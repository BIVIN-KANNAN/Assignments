# %% [markdown]
# <a href="https://colab.research.google.com/github/BIVIN-KANNAN/Assignments/blob/main/Assignment_4__Bivin_k_k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Assignment on preprocessing**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1. Load the dataset into python environment

# %%
data=pd.read_csv('/content/titanic_dataset.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 2. Make 'PassengerId' as the index column

# %%
data.set_index("PassengerId", inplace=True)

# %%
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# 3. Check the basic details of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# 4. Fill in all the missing values present in all the columns in the dataset

# %%
missing_values = data.isnull().sum()

# %%
missing_values
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
# Fill in missing values with 0
data.fillna(0, inplace=True)

# %%
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# 5. Check and handle outliers in at least 3 columns in the dataset

# %%
data.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
columns_to_check = ['Pclass', 'Age', 'SibSp']

# Visualize data distribution using box plots
plt.figure(figsize=(12, 6))
for i, col in enumerate(columns_to_check, 1):
    plt.subplot(1, len(columns_to_check), i)
    sns.boxplot(x=data[col])
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
from scipy import stats
z_scores = np.abs(stats.zscore(data[columns_to_check]))
threshold = 3
outliers = (z_scores > threshold).any(axis=1)

# %%
z_scores
# Out:
#                Pclass       Age     SibSp
# PassengerId
# 1            0.827377  0.102313  0.432793
# 2            1.566107  0.807492  0.432793
# 3            0.827377  0.125138  0.474545
# 4            1.566107  0.636903  0.432793
# 5            0.827377  0.636903  0.474545
# ...               ...       ...       ...
# 887          0.369365  0.182001  0.474545
# 888          1.566107  0.272901  0.474545
# 889          0.827377  1.353294  0.432793
# 890          1.566107  0.125138  0.474545
# 891          0.827377  0.466315  0.474545
#
# [891 rows x 3 columns]

# %% [markdown]
# 6. Do min max scaling on the feature set (Take 'Survived' as target)

# %%
from sklearn.preprocessing import MinMaxScaler

numeric_columns = data.select_dtypes(include=['int64', 'float64']).columns

X = data[numeric_columns].drop(columns=['Survived'])  # Features
y = data['Survived']  # Target

# Initialize MinMaxScaler
scaler = MinMaxScaler()

# Fit scaler to the features and transform them
X_scaled = scaler.fit_transform(X)

# Convert scaled features back to DataFrame
X_scaled_data = pd.DataFrame(X_scaled, columns=X.columns)

# Concatenate scaled features with the target variable
data_scaled = pd.concat([X_scaled_data, y], axis=1)

# %%
data_scaled
# Out:
#      Pclass     Age  SibSp     Parch      Fare  Survived
# 0       1.0  0.2750  0.125  0.000000  0.014151       NaN
# 1       0.0  0.4750  0.125  0.000000  0.139136       0.0
# 2       1.0  0.3250  0.000  0.000000  0.015469       1.0
# 3       0.0  0.4375  0.125  0.000000  0.103644       1.0
# 4       1.0  0.4375  0.000  0.000000  0.015713       1.0
# ..      ...     ...    ...       ...       ...       ...
# 887     0.0  0.2375  0.000  0.000000  0.058556       0.0
# 888     1.0  0.0000  0.125  0.333333  0.045771       1.0
# 889     0.0  0.3250  0.000  0.000000  0.058556       0.0
# 890     1.0  0.4000  0.000  0.000000  0.015127       1.0
# 891     NaN     NaN    NaN       NaN       NaN       0.0
#
# [892 rows x 6 columns]
